# %%
# %matplotlib inline

# %% [markdown]
# #### Importing Libaries for Investigation

# %%
#### Importing the Required Libraries:
import numpy as np #importing numpy
import pandas as pd # importing pandas
import matplotlib.pyplot as plt # importing matplotlib
import seaborn as sns # importing seaborn
import scipy.stats as ss # importing scipy

# %%
df = pd.read_csv("https://raw.githubusercontent.com/martinaobrien/FUNDAMENTALS-OF-DATA-ANALYSIS-Project-2019/master/tips.csv") 
# importing the data set from the url with the notebook
# to display the dataframe, use the command df

# %%
df.head (10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.distplot ("total_bill", "tip", (data = df))
# Out:
#   File "<ipython-input-41-6f2261e3b0ed>", line 1
#     sns.distplot ("total_bill", "tip", (data = df))
#                                              ^
# SyntaxError: invalid syntax

# %%
sns.distplot (df ["total_bill"], bins=30)

# %%
df.boxplot(column='total_bill', by = 'sex')

# %%
temp3 = pd.crosstab(df['sex'], df['smoker'])
temp3.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)

# %%
sns.barplot (x ='sex', y ='tip', data = df, estimator = np.std)
# Out:
# C:\Users\Owner1\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.countplot (x = 'sex', data = df)

# %%
sns.boxplot (x = 'day', y = 'total_bill', data = df, hue = 'sex')

# %%
sns.violinplot (x = 'day', y = 'total_bill', data = df, hue ='sex',splits= 'true')

# %%
sns.violinplot (x = 'day', y = 'total_bill', data = df,)

# %%
sns.stripplot (x = 'day', y = 'total_bill', data = df, jitter = True, hue = 'sex', split = True)
# Out:
# C:\Users\Owner1\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot (x = 'day', y = 'total_bill', data = df)
sns.swarmplot (x = 'day', y = 'total_bill', data = df, color= 'black')

sns.distplot (df ["total_bill"], bins=30)

# %%
sns.swarmplot (x = 'day', y = 'total_bill', data = df)

# %% [markdown]
# Most of your total bills are between 10 dollars and 20 dollars

# %%
sns.jointplot (x = 'total_bill', y = 'tip' , data =df, kind = 'reg')

# %%
sns.pairplot (df)

# %%
sns.pairplot (df, hue='sex')

# %%
sns.pairplot (df, hue='smoker')

# %%
sns.pairplot (df, hue='day')

# %%
sns.pairplot (df, hue='time')

# %% [markdown]
# #### Inputs and Outputs

# %%
import pandas as pd
import sklearn.neighbors as nei
import seaborn as sns

# %%
inputs = df [[ "total_bill", "tip" ,"size" ]]
outputs = df [ "smoker"]

# %%
inputs
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# 5         25.29  4.71     4
# 6          8.77  2.00     2
# 7         26.88  3.12     4
# 8         15.04  1.96     2
# 9         14.78  3.23     2
# 10        10.27  1.71     2
# 11        35.26  5.00     4
# 12        15.42  1.57     2
# 13        18.43  3.00     4
# 14        14.83  3.02     2
# 15        21.58  3.92     2
# 16        10.33  1.67     3
# 17        16.29  3.71     3
# 18        16.97  3.50     3
# 19        20.65  3.35     3
# 20        17.92  4.08     2
# 21        20.29  2.75     2
# 22        15.77  2.23     2
# 23        39.42  7.58     4
# 24        19.82  3.18     2
# 25        17.81  2.34     4
# 26        13.37  2.00     2
# 27        12.69  2.00     2
# 28        21.70  4.30     2
# 29        19.65  3.00     2
# ..          ...   ...   ...
# 214       28.17  6.50     3
# 215       12.90  1.10     2
# 216       28.15  3.00     5
# 217       11.59  1.50     2
# 218        7.74  1.44     2
# 219       30.14  3.09     4
# 220       12.16  2.20     2
# 221       13.42  3.48     2
# 222        8.58  1.92     1
# 223       15.98  3.00     3
# 224       13.42  1.58     2
# 225       16.27  2.50     2
# 226       10.09  2.00     2
# 227       20.45  3.00     4
# 228       13.28  2.72     2
# 229       22.12  2.88     2
# 230       24.01  2.00     4
# 231       15.69  3.00     3
# 232       11.61  3.39     2
# 233       10.77  1.47     2
# 234       15.53  3.00     2
# 235       10.07  1.25     2
# 236       12.60  1.00     2
# 237       32.83  1.17     2
# 238       35.83  4.67     3
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
outputs
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
# 5       No
# 6       No
# 7       No
# 8       No
# 9       No
# 10      No
# 11      No
# 12      No
# 13      No
# 14      No
# 15      No
# 16      No
# 17      No
# 18      No
# 19      No
# 20      No
# 21      No
# 22      No
# 23      No
# 24      No
# 25      No
# 26      No
# 27      No
# 28      No
# 29      No
#       ...
# 214    Yes
# 215    Yes
# 216    Yes
# 217    Yes
# 218    Yes
# 219    Yes
# 220    Yes
# 221    Yes
# 222    Yes
# 223     No
# 224    Yes
# 225    Yes
# 226    Yes
# 227     No
# 228     No
# 229    Yes
# 230    Yes
# 231    Yes
# 232     No
# 233     No
# 234    Yes
# 235     No
# 236    Yes
# 237    Yes
# 238     No
# 239     No
# 240    Yes
# 241    Yes
# 242     No
# 243     No
# Name: smoker, Length: 244, dtype: object

# %% [markdown]
# #### Classification

# %%
import numpy as np #importing numpy
import pandas as pd # importing pandas
import matplotlib.pyplot as plt # importing matplotlib
import seaborn as sns # importing seaborn
import scipy.stats as ss # importing scipy

# %%
knn = nei.KNeighborsClassifier(n_neighbors=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-157f38a34747> in <module>
# ----> 1 knn = nei.KNeighborsClassifier(n_neighbors=5)
#
# NameError: name 'nei' is not defined

# %%
knn.fit(inputs, outputs)

# %%
df.loc [6]

# %%
knn.predict ([[8.77, 2, 2]])

# %%
#### Importing the Required Libraries:
import numpy as np #importing numpy
import pandas as pd # importing pandas
import matplotlib.pyplot as plt # importing matplotlib
import seaborn as sns # importing seaborn
import scipy.stats as ss # importing scipy

# %%
sns.lmplot(x='total_bill', y='tip', data='df')

# %%
# Plot multiple seaborn histogram in single graph
plt.figure(figsize=(8,4))
sns.distplot(df["total_bill"], bins=10, label="total_bil")
sns.distplot(df["tip"], bins=10, label="tip")
 
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4f55d29450ce> in <module>
#       1 # Plot multiple seaborn histogram in single graph
# ----> 2 plt.figure(figsize=(8,4))
#       3 sns.distplot(df["total_bill"], bins=10, label="total_bil")
#       4 sns.distplot(df["tip"], bins=10, label="tip")
#       5
#
# NameError: name 'plt' is not defined
